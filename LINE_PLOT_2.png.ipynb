# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/historical_automobile_sales.csv"
df = pd.read_csv(url)

# Convert 'Year' to numeric (if not already)
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')

# Group by Year and Vehicle Type and sum the Sales


# Define recession years (2007-2009)
recession_years = list(range(2007, 2010))

# Plotting
plt.figure(figsize=(12, 7))

# Get unique vehicle types


# Plot each vehicle type sales over the years
for v_type in vehicle_types:
    sales_data = df[df['Vehicle_Type'] == v_type].groupby('Year')['Automobile_Sales'].sum().reset_index()
    plt.plot(sales_data['Year'], sales_data['Automobile_Sales'], marker='o', label=v_type)

# Highlight recession period
plt.axvspan(min(recession_years), max(recession_years), color='grey', alpha=0.3, label='Recession Period')

plt.title('Vehicle Sales Trends by Type (with Recession Period Highlighted)')
plt.xlabel('Year')
plt.ylabel('Total Sales')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
